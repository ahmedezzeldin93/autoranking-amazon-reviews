# %%
import pandas as pd 
import gzip

def parse(path): 
    g = gzip.open(path, 'rb') 
    for l in g: 
        yield eval(l) 

def getDF(path): 
    i = 0 
    df = {} 
    for d in parse(path): 
        df[i] = d
        i += 1 
    return pd.DataFrame.from_dict(df, orient='index') 

df = getDF('reviews_Toys_and_Games_5.json.gz')
df
# Out:
#             reviewerID        asin  \
# 0       A1VXOAVRGKGEAK  0439893577
# 1        A8R62G708TSCM  0439893577
# 2       A21KH420DK0ICA  0439893577
# 3        AR29QK6HPFYZ4  0439893577
# 4        ACCH8EOML6FN5  0439893577
# 5       A1EDPGHC9EYBUN  0439893577
# 6       A181ZNB42LISRZ  0439893577
# 7       A1RBEJ5UQ1RWAW  0439893577
# 8        AFGGC7SIV964O  0439893577
# 9       A2XU46XXNV19C8  0439893577
# 10      A1TNIN1HQIW2L6  0439893577
# 11       A5I03TZD4J96V  0439893577
# 12      A2N4973VTYMV52  0439893577
# 13      A11Q7PYQ87R5Y2  0439893577
# 14      A3AJWITG95EY0Q  0439893577
# 15      A137TYEMD68CAQ  0439893577
# 16      A1TLCX2PM0TN8P  0439893577
# 17       AQN75W8HMUFSP  048645195X
# 18      A32WT1ZEE4QGZB  048645195X
# 19      A1X3ESYZ79H59E  048645195X
# 20       AKMEY1BSHSDG7  048645195X
# 21      A2GYEPZKMD3J2Z  048645195X
# 22      A2IB3CUVPRE28M  048645195X
# 23      A1MPWLA14I9OWW  048645195X
# 24       ASVLLLS52G0A8  048645195X
# ...

# %%
df.reviewText
# Out:
# 0         I like the item pricing. My granddaughter want...
# 1         Love the magnet easel... great for moving to d...
# 2         Both sides are magnetic.  A real plus when you...
# 3         Bought one a few years ago for my daughter and...
# 4         I have a stainless steel refrigerator therefor...
# 5         this is a nice magnetic board for the kids to ...
# 6         This is just as I expected. It's not too sturd...
# 7         My granddaughter really really likes this. I l...
# 8         This is good product to have with unlimited po...
# 9         I keep this board on top of the hallway table ...
# 10        Very nice to use with magnet letters and pract...
# 11        Bought this board along with Melissa and Doug ...
# 12        The board had to be put away for my 18 month o...
# 13        sturdy and perfect for coffee table. magnets s...
# 14        We had purchased Melissa & Doug magnets & had ...
# 15        We purchased this to go with the magnetic lett...
# ...
